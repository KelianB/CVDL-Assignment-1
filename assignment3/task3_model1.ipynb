# %% [markdown]
# This is a simple example on how you can use a jupyter notebook to train your model :)

# %%
import torch
import torch.nn as nn
import torchvision
from dataloaders import load_cifar10
from task2 import Trainer, compute_loss_and_accuracy, create_plots

# %%
class ExampleModel(nn.Module):

    def __init__(self,
                 image_channels,
                 num_classes):
        """
            Is called when model is initialized.
            Args:
                image_channels. Number of color channels in image (3)
                num_classes: Number of classes we want to predict (10)
        """
        super().__init__()
        num_filters = 32  # Set number of filters in first conv layer
        self.num_classes = num_classes
        # Define the convolutional layers
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(
                in_channels=image_channels,
                out_channels=num_filters,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.Conv2d(
                in_channels=num_filters,
                out_channels=2*num_filters,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(2*num_filters),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout2d(p=0.1),
            
            nn.Conv2d(
                in_channels=2*num_filters,
                out_channels=4*num_filters,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(4*num_filters),
            nn.ReLU(),
            nn.Conv2d(
                in_channels=4*num_filters,
                out_channels=8*num_filters,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(8*num_filters),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout2d(p=0.1),
            
            
            nn.Conv2d(
                in_channels=8*num_filters,
                out_channels=16*num_filters,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(16*num_filters),
            nn.ReLU(),
            nn.Conv2d(
                in_channels=16*num_filters,
                out_channels=32*num_filters,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(32*num_filters),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout2d(p=0.1),
        )
        # The output of feature_extractor will be [batch_size, num_filters, 16, 16]
        self.num_output_features = 32 * num_filters * 4 * 4
        # Initialize our last fully connected layer
        # Inputs all extracted features from the convolutional layers
        # Outputs num_classes predictions, 1 for each class.
        # There is no need for softmax activation function, as this is
        # included with nn.CrossEntropyLoss
        self.classifier = nn.Sequential(
            nn.Linear(self.num_output_features, 64),
            nn.Sigmoid(),
            nn.Linear(64, num_classes),
        )

    def forward(self, x):
        """
        Performs a forward pass through the model
        Args:
            x: Input image, shape: [batch_size, 3, 32, 32]
        """
        batch_size = x.shape[0]
        out = self.feature_extractor(x)
        out = out.view(batch_size, -1)
        out = self.classifier(out)        
        expected_shape = (batch_size, self.num_classes)
        assert out.shape == (batch_size, self.num_classes),\
            f"Expected output of forward pass to be: {expected_shape}, but got: {out.shape}"
        return out

# %%
epochs = 10
batch_size = 64
learning_rate = 1e-4
early_stop_count = 4
dataloaders = load_cifar10(batch_size)
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model,
    dataloaders
)
trainer.optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout2d(p=0.1, inplace=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout2d(p=0.1, inplace=False)
#     (16): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): ReLU()
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout2d(p=0.1, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=64, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch:  0	Batches per seconds: 32.82	Global step:    352	Validation Loss: 1.49,	Validation Accuracy: 55.700
# Epoch:  0	Batches per seconds: 30.84	Global step:    704	Validation Loss: 1.24,	Validation Accuracy: 63.400
# Epoch:  1	Batches per seconds: 30.08	Global step:   1056	Validation Loss: 1.12,	Validation Accuracy: 66.940
# Epoch:  1	Batches per seconds: 29.78	Global step:   1408	Validation Loss: 0.94,	Validation Accuracy: 72.180
# Epoch:  2	Batches per seconds: 29.54	Global step:   1760	Validation Loss: 0.86,	Validation Accuracy: 74.360
# Epoch:  2	Batches per seconds: 29.41	Global step:   2112	Validation Loss: 0.80,	Validation Accuracy: 75.160
# Epoch:  3	Batches per seconds: 29.29	Global step:   2464	Validation Loss: 0.75,	Validation Accuracy: 76.500
# Epoch:  3	Batches per seconds: 29.22	Global step:   2816	Validation Loss: 0.70,	Validation Accuracy: 77.980
# Epoch:  4	Batches per seconds: 29.14	Global step:   3168	Validation Loss: 0.69,	Validation Accuracy: 77.300
# Epoch:  4	Batches per seconds: 29.10	Global step:   3520	Validation Loss: 0.62,	Validation Accuracy: 80.260
# Epoch:  5	Batches per seconds: 29.04	Global step:   3872	Validation Loss: 0.60,	Validation Accuracy: 80.260
# Epoch:  5	Batches per seconds: 29.01	Global step:   4224	Validation Loss: 0.61,	Validation Accuracy: 79.940
# Epoch:  6	Batches per seconds: 28.99	Global step:   4576	Validation Loss: 0.57,	Validation Accuracy: 81.200
# Epoch:  6	Batches per seconds: 28.97	Global step:   4928	Validation Loss: 0.53,	Validation Accuracy: 82.820
# Epoch:  7	Batches per seconds: 28.93	Global step:   5280	Validation Loss: 0.53,	Validation Accuracy: 82.620
# Epoch:  7	Batches per seconds: 28.94	Global step:   5632	Validation Loss: 0.52,	Validation Accuracy: 82.700
# Epoch:  8	Batches per seconds: 28.90	Global step:   5984	Validation Loss: 0.51,	Validation Accuracy: 83.360
# Epoch:  8	Batches per seconds: 28.89	Global step:   6336	Validation Loss: 0.53,	Validation Accuracy: 82.500
# Epoch:  9	Batches per seconds: 28.88	Global step:   6688	Validation Loss: 0.51,	Validation Accuracy: 82.640
# Epoch:  9	Batches per seconds: 28.89	Global step:   7040	Validation Loss: 0.51,	Validation Accuracy: 83.540

# %%
create_plots(trainer, "task3_1")

# %%
dataloader_train, dataloader_val, dataloader_test = dataloaders
trainer.load_best_model()
print("Train Accuracy:", compute_loss_and_accuracy(dataloader_train, trainer.model, nn.CrossEntropyLoss())[1])
print("Validation Accuracy:", compute_loss_and_accuracy(dataloader_val, trainer.model, nn.CrossEntropyLoss())[1])
print("Test Accuracy:", compute_loss_and_accuracy(dataloader_test, trainer.model, nn.CrossEntropyLoss())[1])
# Out:
# Train Accuracy: tensor(94.5733, device='cuda:0')
# Validation Accuracy: tensor(82.5400, device='cuda:0')
# Test Accuracy: tensor(80.8700, device='cuda:0')
